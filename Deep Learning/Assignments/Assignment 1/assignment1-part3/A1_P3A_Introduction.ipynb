# %% [markdown]
# <a href="https://colab.research.google.com/github/the-visionary/assignment1/blob/main/assignment1-part3/A1_P3A_Introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 1 Part 3A Introduction: Multi-label Image Classification

# %%
# Steps to load extra files and download dataset.
import os
# !git clone "https://vipulrawat008:Invincible007!@github.com/the-visionary/assignment1.git"
os.chdir('/content')
os.chdir('assignment1')
os.chdir('assignment1-part3')
assert (os.getcwd() == '/content/assignment1/assignment1-part3')

# !bash download_data.sh
assert (os.getcwd() == '/content/assignment1/assignment1-part3')
# Out:
# Cloning into 'assignment1'...
# remote: Enumerating objects: 59, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 59 (delta 20), reused 32 (delta 4), pack-reused 0
# Unpacking objects: 100% (59/59), done.
# --2021-02-27 15:58:30--  http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtrainval_06-Nov-2007.tar
# Resolving host.robots.ox.ac.uk (host.robots.ox.ac.uk)... 129.67.94.152
# Connecting to host.robots.ox.ac.uk (host.robots.ox.ac.uk)|129.67.94.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 460032000 (439M) [application/x-tar]
# Saving to: ‘VOCtrainval_06-Nov-2007.tar’
#
# VOCtrainval_06-Nov- 100%[===================>] 438.72M  69.4MB/s    in 6.6s
#
# 2021-02-27 15:58:37 (66.8 MB/s) - ‘VOCtrainval_06-Nov-2007.tar’ saved [460032000/460032000]
#
# --2021-02-27 15:58:39--  http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtest_06-Nov-2007.tar
# Resolving host.robots.ox.ac.uk (host.robots.ox.ac.uk)... 129.67.94.152
# Connecting to host.robots.ox.ac.uk (host.robots.ox.ac.uk)|129.67.94.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 451020800 (430M) [application/x-tar]
# Saving to: ‘VOCtest_06-Nov-2007.tar’
#
# VOCtest_06-Nov-2007 100%[===================>] 430.13M  67.7MB/s    in 6.5s
#
# 2021-02-27 15:58:45 (66.4 MB/s) - ‘VOCtest_06-Nov-2007.tar’ saved [451020800/451020800]

# %%
os.chdir('/content')
os.chdir('assignment1')
os.chdir('assignment1-part3')

# %%
# !pip install torch==1.5.1 torchvision==0.6.1
# Out:
# Collecting torch==1.5.1
#   Downloading https://files.pythonhosted.org/packages/a4/cf/007b6de316c9f3d4cb315a60c308342cc299e464167f5ebc369e93b5e23a/torch-1.5.1-cp37-cp37m-manylinux1_x86_64.whl (753.2MB)
#      |████████████████████████████████| 753.2MB 25kB/s
# Collecting torchvision==0.6.1
#   Downloading https://files.pythonhosted.org/packages/f4/ef/c32275c040f12f24adcd6302f0f3cd12cc432e408ce4ea521600e8fd989c/torchvision-0.6.1-cp37-cp37m-manylinux1_x86_64.whl (6.6MB)
#      |████████████████████████████████| 6.6MB 18.7MB/s
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from torch==1.5.1) (0.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch==1.5.1) (1.19.5)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.6.1) (7.0.0)
# Installing collected packages: torch, torchvision
#   Found existing installation: torch 1.7.1+cu101
#     Uninstalling torch-1.7.1+cu101:
#       Successfully uninstalled torch-1.7.1+cu101
#   Found existing installation: torchvision 0.8.2+cu101
#     Uninstalling torchvision-0.8.2+cu101:
#       Successfully uninstalled torchvision-0.8.2+cu101
# Successfully installed torch-1.5.1 torchvision-0.6.1

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torchvision

from torchvision import transforms
from sklearn.metrics import average_precision_score
from PIL import Image, ImageDraw
# from kaggle_submission import output_submission_csv
import matplotlib.pyplot as plt
from classifier import SimpleClassifier, Classifier#, AlexNet
from voc_dataloader import VocDataset, VOC_CLASSES

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Multi-label Classification
# In this assignment, you train a classifier to do multi-label classificaton on the PASCAL VOC 2007 dataset. The dataset has 20 different class which can appear in any given image. Your classifier will predict whether each class appears in an image. This task is slightly different from exclusive multiclass classification like the ImageNet competition where only a single most appropriate class is predicted for an image.
#
# ## Part 3A
# You will use this notebook to warm up with pytorch.
#
# ### What to do
# In part 3A, You are asked to run below experiments. You don't need to change hyperparameters for this Part 3A's experiments. (the following code provides everything that you will need.)
# 1. to train a simple network (defined in ```classifiers.py```)
# 2. to train the AlexNet (PyTorch built-in)
#     - from scratch
#     - finetuning AlexNet pretrained on ImageNet
#
#
#
# ### What to submit
# We ask you to run the following code and report the results in your homework submission. You may want to leverage this part 3A get yourself familiar with PyTorch.
#
# You will the need the numbers and plots this notebook outputs for reports, but you are not required to submit this notebook as a printed pdf.

# %% [markdown]
# ## Reading Pascal Data

# %% [markdown]
# ### Loading Training Data

# %% [markdown]
# In the following cell we will load the training data and also apply some transforms to the data.

# %%
# Transforms applied to the training data
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std= [0.229, 0.224, 0.225])

train_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.ToTensor(),
            normalize
        ])

# %%
ds_train = VocDataset('VOCdevkit_2007/VOC2007/','train',train_transform)
# Out:
# /content/assignment1/assignment1-part3/voc_dataloader.py:109: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return np.array(names), np.array(labels).astype(np.float32), np.array(box_indices), label_order

# %% [markdown]
# ### Loading Validation Data

# %% [markdown]
# We will load the test data for the PASCAL VOC 2007 dataset. Do __NOT__ add data augmentation transforms to validation data.

# %%
# Transforms applied to the testing data
test_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.ToTensor(),
            normalize,
        ])

# %%
ds_val = VocDataset('VOCdevkit_2007/VOC2007/','val',test_transform)
# Out:
# /content/assignment1/assignment1-part3/voc_dataloader.py:109: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return np.array(names), np.array(labels).astype(np.float32), np.array(box_indices), label_order

# %% [markdown]
# ### Visualizing the Data
#
# PASCAL VOC has bounding box annotations in addition to class labels. Use the following code to visualize some random examples and corresponding annotations from the train set.

# %%
for i in range(5):
    idx = np.random.randint(0, len(ds_train.names)+1)
    _imgpath = os.path.join('VOCdevkit_2007/VOC2007/', 'JPEGImages', ds_train.names[idx]+'.jpg')
    img = Image.open(_imgpath).convert('RGB')
    draw = ImageDraw.Draw(img)
    for j in range(len(ds_train.box_indices[idx])):
        obj = ds_train.box_indices[idx][j]
        draw.rectangle(list(obj), outline=(255,0,0))
        draw.text(list(obj[0:2]), ds_train.classes[ds_train.label_order[idx][j]], fill=(0,255,0))
    plt.figure(figsize = (10,10))
    plt.imshow(np.array(img))

# %% [markdown]
# # Classification

# %%
# def collate_fn(batch):
#     return tuple(zip(*batch))

# %%
# declare what device to use: gpu/cpu
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
train_loader = torch.utils.data.DataLoader(dataset=ds_train,
                                               batch_size=50, 
                                               shuffle=True,
                                            #    collate_fn=lambda x: x,
                                               num_workers=1)

# %%
val_loader = torch.utils.data.DataLoader(dataset=ds_val,
                                               batch_size=50, 
                                               shuffle=True,
                                            #    collate_fn=lambda x: x,
                                               num_workers=1)

# %%
def train_classifier(train_loader, classifier, criterion, optimizer):
    classifier.train()
    loss_ = 0.0
    losses = []
    for i, (images, labels, _) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        logits = classifier(images)
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()
        losses.append(loss)
    return torch.stack(losses).mean().item()

# %%
def test_classifier(test_loader, classifier, criterion, print_ind_classes=True, print_total=True):
    classifier.eval()
    losses = []
    with torch.no_grad():
        y_true = np.zeros((0,21))
        y_score = np.zeros((0,21))
        for i, (images, labels, _) in enumerate(test_loader):
            images, labels = images.to(device), labels.to(device)
            logits = classifier(images)
            y_true = np.concatenate((y_true, labels.cpu().numpy()), axis=0)
            y_score = np.concatenate((y_score, logits.cpu().numpy()), axis=0)
            loss = criterion(logits, labels)
            losses.append(loss.item())
        aps = []
        # ignore first class which is background
        for i in range(1, y_true.shape[1]):
            ap = average_precision_score(y_true[:, i], y_score[:, i])
            if print_ind_classes:
                print('-------  Class: {:<12}     AP: {:>8.4f}  -------'.format(VOC_CLASSES[i], ap))
            aps.append(ap)
        
        mAP = np.mean(aps)
        test_loss = np.mean(losses)
        if print_total:
            print('mAP: {0:.4f}'.format(mAP))
            print('Avg loss: {}'.format(test_loss))
        
    return mAP, test_loss, aps

# %%
# plot functions
def plot_losses(train, val, test_frequency, num_epochs):
    plt.plot(train, label="train")
    indices = [i for i in range(num_epochs) if ((i+1)%test_frequency == 0 or i ==0)]
    plt.plot(indices, val, label="val")
    plt.title("Loss Plot")
    plt.ylabel("Loss")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()
    
def plot_mAP(train, val, test_frequency, num_epochs):
    indices = [i for i in range(num_epochs) if ((i+1)%test_frequency == 0 or i ==0)]
    plt.plot(indices, train, label="train")
    plt.plot(indices, val, label="val")
    plt.title("mAP Plot")
    plt.ylabel("mAP")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()

# %% [markdown]
# ## Training the network
#
# The simple network you are given as is will allow you to reach around 0.15-0.2 mAP. In this project, you will find ways to design a better network. Save plots and final test mAP scores as you will be adding these to the writeup.

# %%
def train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency=5):
    train_losses = []
    train_mAPs = []
    val_losses = []
    val_mAPs = []

    for epoch in range(1,num_epochs+1):
        print("Starting epoch number " + str(epoch))
        train_loss = train_classifier(train_loader, classifier, criterion, optimizer)
        train_losses.append(train_loss)
        print("Loss for Training on Epoch " +str(epoch) + " is "+ str(train_loss))
        if(epoch%test_frequency==0 or epoch==1):
            mAP_train, _, _ = test_classifier(train_loader, classifier, criterion, False, False)
            train_mAPs.append(mAP_train)
            mAP_val, val_loss, _ = test_classifier(val_loader, classifier, criterion)
            print('Evaluating classifier')
            print("Mean Precision Score for Testing on Epoch " +str(epoch) + " is "+ str(mAP_val))
            val_losses.append(val_loss)
            val_mAPs.append(mAP_val)
    
    return classifier, train_losses, val_losses, train_mAPs, val_mAPs

# %%
classifier = SimpleClassifier().to(device)
# You can can use this function to reload a network you have already saved previously
#classifier.load_state_dict(torch.load('voc_classifier.pth'))

# %%
criterion = nn.MultiLabelSoftMarginLoss()
optimizer = torch.optim.SGD(classifier.parameters(), lr=0.01, momentum=0.9)

# %%
# Training the Classifier
num_epochs = 20
test_frequency = 5

classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.5622367262840271
# -------  Class: aeroplane        AP:   0.1695  -------
# -------  Class: bicycle          AP:   0.0508  -------
# -------  Class: bird             AP:   0.1086  -------
# -------  Class: boat             AP:   0.1242  -------
# -------  Class: bottle           AP:   0.0367  -------
# -------  Class: bus              AP:   0.0325  -------
# -------  Class: car              AP:   0.1222  -------
# -------  Class: cat              AP:   0.0810  -------
# -------  Class: chair            AP:   0.1064  -------
# -------  Class: cow              AP:   0.0315  -------
# -------  Class: diningtable      AP:   0.0439  -------
# -------  Class: dog              AP:   0.1105  -------
# -------  Class: horse            AP:   0.0503  -------
# -------  Class: motorbike        AP:   0.0455  -------
# -------  Class: person           AP:   0.3548  -------
# -------  Class: pottedplant      AP:   0.0417  -------
# -------  Class: sheep            AP:   0.0252  -------
# -------  Class: sofa             AP:   0.0776  -------
# -------  Class: train            AP:   0.0362  -------
# -------  Class: tvmonitor        AP:   0.0507  -------
# mAP: 0.0850
# Avg loss: 0.25355657263129366
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.08498484376620787
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.2520917057991028
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.24239510297775269
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.24005720019340515
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.24173015356063843
# -------  Class: aeroplane        AP:   0.0786  -------
# -------  Class: bicycle          AP:   0.0433  -------
# -------  Class: bird             AP:   0.1122  -------
# -------  Class: boat             AP:   0.0700  -------
# -------  Class: bottle           AP:   0.0478  -------
# -------  Class: bus              AP:   0.0280  -------
# -------  Class: car              AP:   0.1174  -------
# -------  Class: cat              AP:   0.1110  -------
# -------  Class: chair            AP:   0.1369  -------
# -------  Class: cow              AP:   0.0319  -------
# -------  Class: diningtable      AP:   0.0593  -------
# -------  Class: dog              AP:   0.1330  -------
# -------  Class: horse            AP:   0.0506  -------
# -------  Class: motorbike        AP:   0.0413  -------
# -------  Class: person           AP:   0.4359  -------
# -------  Class: pottedplant      AP:   0.0464  -------
# -------  Class: sheep            AP:   0.0293  -------
# -------  Class: sofa             AP:   0.1122  -------
# -------  Class: train            AP:   0.0351  -------
# -------  Class: tvmonitor        AP:   0.0545  -------
# mAP: 0.0887
# Avg loss: 0.2358225338599261
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.08873245834127172
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.23810291290283203
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.23977454006671906
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.2356778383255005
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.2358553409576416
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.23399432003498077
# -------  Class: aeroplane        AP:   0.1794  -------
# -------  Class: bicycle          AP:   0.0466  -------
# -------  Class: bird             AP:   0.1208  -------
# -------  Class: boat             AP:   0.1339  -------
# -------  Class: bottle           AP:   0.0621  -------
# -------  Class: bus              AP:   0.0382  -------
# -------  Class: car              AP:   0.1530  -------
# -------  Class: cat              AP:   0.1137  -------
# -------  Class: chair            AP:   0.1644  -------
# -------  Class: cow              AP:   0.0375  -------
# -------  Class: diningtable      AP:   0.0707  -------
# -------  Class: dog              AP:   0.1280  -------
# -------  Class: horse            AP:   0.0564  -------
# -------  Class: motorbike        AP:   0.0441  -------
# -------  Class: person           AP:   0.4834  -------
# -------  Class: pottedplant      AP:   0.0461  -------
# -------  Class: sheep            AP:   0.0351  -------
# -------  Class: sofa             AP:   0.1322  -------
# -------  Class: train            AP:   0.0489  -------
# -------  Class: tvmonitor        AP:   0.0586  -------
# mAP: 0.1077
# Avg loss: 0.231222798426946
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.10766324941436915
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.23277364671230316
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.23034435510635376
# Starting epoch number 13
# Loss for Training on Epoch 13 is 0.2253313958644867
# Starting epoch number 14
# Loss for Training on Epoch 14 is 0.225058913230896
# Starting epoch number 15
# Loss for Training on Epoch 15 is 0.22407136857509613
# -------  Class: aeroplane        AP:   0.2722  -------
# -------  Class: bicycle          AP:   0.0608  -------
# -------  Class: bird             AP:   0.1066  -------
# -------  Class: boat             AP:   0.2111  -------
# -------  Class: bottle           AP:   0.0804  -------
# -------  Class: bus              AP:   0.0600  -------
# -------  Class: car              AP:   0.1826  -------
# -------  Class: cat              AP:   0.1271  -------
# -------  Class: chair            AP:   0.2060  -------
# -------  Class: cow              AP:   0.0485  -------
# -------  Class: diningtable      AP:   0.1284  -------
# -------  Class: dog              AP:   0.1444  -------
# -------  Class: horse            AP:   0.0782  -------
# -------  Class: motorbike        AP:   0.0528  -------
# -------  Class: person           AP:   0.5101  -------
# -------  Class: pottedplant      AP:   0.0605  -------
# -------  Class: sheep            AP:   0.0459  -------
# -------  Class: sofa             AP:   0.1509  -------
# -------  Class: train            AP:   0.1132  -------
# -------  Class: tvmonitor        AP:   0.0776  -------
# mAP: 0.1359
# Avg loss: 0.22459923753551408
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.13586376672585931
# Starting epoch number 16
# Loss for Training on Epoch 16 is 0.224028080701828
# Starting epoch number 17
# Loss for Training on Epoch 17 is 0.22357989847660065
# Starting epoch number 18
# Loss for Training on Epoch 18 is 0.22061200439929962
# Starting epoch number 19
# Loss for Training on Epoch 19 is 0.2209300994873047
# Starting epoch number 20
# Loss for Training on Epoch 20 is 0.21946430206298828
# -------  Class: aeroplane        AP:   0.3129  -------
# -------  Class: bicycle          AP:   0.0734  -------
# -------  Class: bird             AP:   0.1073  -------
# -------  Class: boat             AP:   0.2140  -------
# -------  Class: bottle           AP:   0.0912  -------
# -------  Class: bus              AP:   0.0709  -------
# -------  Class: car              AP:   0.2269  -------
# -------  Class: cat              AP:   0.1345  -------
# -------  Class: chair            AP:   0.2370  -------
# -------  Class: cow              AP:   0.0630  -------
# -------  Class: diningtable      AP:   0.1707  -------
# -------  Class: dog              AP:   0.1389  -------
# -------  Class: horse            AP:   0.1153  -------
# -------  Class: motorbike        AP:   0.0736  -------
# -------  Class: person           AP:   0.5127  -------
# -------  Class: pottedplant      AP:   0.0728  -------
# -------  Class: sheep            AP:   0.0414  -------
# -------  Class: sofa             AP:   0.1775  -------
# -------  Class: train            AP:   0.1517  -------
# -------  Class: tvmonitor        AP:   0.1150  -------
# mAP: 0.1550
# Avg loss: 0.22070468407051236
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.155030745622131

# %%
# Compare train and validation metrics
plot_losses(train_losses, val_losses, test_frequency, num_epochs)
plot_mAP(train_mAPs, val_mAPs, test_frequency, num_epochs)

# %%
# Save the clssifier network
# Suggestion: you can save checkpoints of your network during training and reload them later
torch.save(classifier.state_dict(), './voc_simple_classifier.pth')

# %% [markdown]
# # Evaluate on test set

# %%
ds_test = VocDataset('VOCdevkit_2007/VOC2007test/','test', test_transform)

test_loader = torch.utils.data.DataLoader(dataset=ds_test,
                                               batch_size=50, 
                                               shuffle=False,
                                               num_workers=1)

# Transforms applied to the testing data
test_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.ToTensor(),
            normalize,
        ])

mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)

# %%
output_submission_csv('my_solution.csv', test_aps)

# %% [markdown]
# # AlexNet Baselines (From Scratch)

# %% [markdown]
# AlexNet was one of the earliest deep learning models to have success in classification. In this section we will be running classification with AlexNet as a baseline. Furthermore, we will run an ImageNet-pretrained AlexNet to observe the impact of well-trained features. Save plots and final test mAP scores as you will be adding these to the writeup.

# %% [markdown]
# ## Running AlexNet
#
# In this section, we train AlexNet from scratch using the same hyperparameters as our previous experiment.

# %%
num_epochs = 20
test_frequency = 5

# Change classifier to AlexNet
classifier = torchvision.models.alexnet(pretrained=False)
classifier.classifier._modules['6'] = nn.Linear(4096, 21)   
classifier = classifier.to(device)

criterion = nn.MultiLabelSoftMarginLoss()

optimizer = torch.optim.SGD(classifier.parameters(), lr=0.01, momentum=0.9)

# %%
classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.5460206866264343
# -------  Class: aeroplane        AP:   0.0928  -------
# -------  Class: bicycle          AP:   0.0412  -------
# -------  Class: bird             AP:   0.1026  -------
# -------  Class: boat             AP:   0.0955  -------
# -------  Class: bottle           AP:   0.0426  -------
# -------  Class: bus              AP:   0.0277  -------
# -------  Class: car              AP:   0.1067  -------
# -------  Class: cat              AP:   0.1033  -------
# -------  Class: chair            AP:   0.1192  -------
# -------  Class: cow              AP:   0.0350  -------
# -------  Class: diningtable      AP:   0.0529  -------
# -------  Class: dog              AP:   0.1186  -------
# -------  Class: horse            AP:   0.0456  -------
# -------  Class: motorbike        AP:   0.0344  -------
# -------  Class: person           AP:   0.3523  -------
# -------  Class: pottedplant      AP:   0.0438  -------
# -------  Class: sheep            AP:   0.0413  -------
# -------  Class: sofa             AP:   0.1029  -------
# -------  Class: train            AP:   0.0402  -------
# -------  Class: tvmonitor        AP:   0.0477  -------
# mAP: 0.0823
# Avg loss: 0.31276869656992895
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.08231225260158151
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.2485632300376892
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.24433700740337372
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.24409259855747223
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.2421858012676239
# -------  Class: aeroplane        AP:   0.0948  -------
# -------  Class: bicycle          AP:   0.0463  -------
# -------  Class: bird             AP:   0.1155  -------
# -------  Class: boat             AP:   0.1038  -------
# -------  Class: bottle           AP:   0.0421  -------
# -------  Class: bus              AP:   0.0293  -------
# -------  Class: car              AP:   0.1137  -------
# -------  Class: cat              AP:   0.0901  -------
# -------  Class: chair            AP:   0.1213  -------
# -------  Class: cow              AP:   0.0354  -------
# -------  Class: diningtable      AP:   0.0537  -------
# -------  Class: dog              AP:   0.1169  -------
# -------  Class: horse            AP:   0.0479  -------
# -------  Class: motorbike        AP:   0.0375  -------
# -------  Class: person           AP:   0.3623  -------
# -------  Class: pottedplant      AP:   0.0468  -------
# -------  Class: sheep            AP:   0.0404  -------
# -------  Class: sofa             AP:   0.0964  -------
# -------  Class: train            AP:   0.0408  -------
# -------  Class: tvmonitor        AP:   0.0487  -------
# mAP: 0.0842
# Avg loss: 0.2395042531630572
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.0841877618469172
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.24349567294120789
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.24498401582241058
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.24174365401268005
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.2420697659254074
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.2426367551088333
# -------  Class: aeroplane        AP:   0.0886  -------
# -------  Class: bicycle          AP:   0.0495  -------
# -------  Class: bird             AP:   0.1222  -------
# -------  Class: boat             AP:   0.0988  -------
# -------  Class: bottle           AP:   0.0412  -------
# -------  Class: bus              AP:   0.0304  -------
# -------  Class: car              AP:   0.1218  -------
# -------  Class: cat              AP:   0.0890  -------
# -------  Class: chair            AP:   0.1270  -------
# -------  Class: cow              AP:   0.0363  -------
# -------  Class: diningtable      AP:   0.0547  -------
# -------  Class: dog              AP:   0.1197  -------
# -------  Class: horse            AP:   0.0506  -------
# -------  Class: motorbike        AP:   0.0402  -------
# -------  Class: person           AP:   0.3926  -------
# -------  Class: pottedplant      AP:   0.0490  -------
# -------  Class: sheep            AP:   0.0436  -------
# -------  Class: sofa             AP:   0.0948  -------
# -------  Class: train            AP:   0.0425  -------
# -------  Class: tvmonitor        AP:   0.0506  -------
# mAP: 0.0872
# Avg loss: 0.24043427173997842
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.0871605468630864
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.23994854092597961
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.2401612550020218
# Starting epoch number 13
# Loss for Training on Epoch 13 is 0.2445165365934372
# Starting epoch number 14
# Loss for Training on Epoch 14 is 0.2445593625307083
# Starting epoch number 15
# Loss for Training on Epoch 15 is 0.24059581756591797
# -------  Class: aeroplane        AP:   0.0895  -------
# -------  Class: bicycle          AP:   0.0519  -------
# -------  Class: bird             AP:   0.1274  -------
# -------  Class: boat             AP:   0.0884  -------
# -------  Class: bottle           AP:   0.0443  -------
# -------  Class: bus              AP:   0.0316  -------
# -------  Class: car              AP:   0.1330  -------
# -------  Class: cat              AP:   0.0927  -------
# -------  Class: chair            AP:   0.1420  -------
# -------  Class: cow              AP:   0.0372  -------
# -------  Class: diningtable      AP:   0.0623  -------
# -------  Class: dog              AP:   0.1214  -------
# -------  Class: horse            AP:   0.0536  -------
# -------  Class: motorbike        AP:   0.0431  -------
# -------  Class: person           AP:   0.5022  -------
# -------  Class: pottedplant      AP:   0.0546  -------
# -------  Class: sheep            AP:   0.0501  -------
# -------  Class: sofa             AP:   0.1017  -------
# -------  Class: train            AP:   0.0476  -------
# -------  Class: tvmonitor        AP:   0.0519  -------
# mAP: 0.0963
# Avg loss: 0.23710846784068088
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.09631464193892224
# Starting epoch number 16
# Loss for Training on Epoch 16 is 0.23790571093559265
# Starting epoch number 17
# Loss for Training on Epoch 17 is 0.23652338981628418
# Starting epoch number 18
# Loss for Training on Epoch 18 is 0.2355271577835083
# Starting epoch number 19
# Loss for Training on Epoch 19 is 0.23373457789421082
# Starting epoch number 20
# Loss for Training on Epoch 20 is 0.23196926712989807
# -------  Class: aeroplane        AP:   0.2432  -------
# -------  Class: bicycle          AP:   0.0613  -------
# -------  Class: bird             AP:   0.1329  -------
# -------  Class: boat             AP:   0.1923  -------
# -------  Class: bottle           AP:   0.0628  -------
# -------  Class: bus              AP:   0.0487  -------
# -------  Class: car              AP:   0.1813  -------
# -------  Class: cat              AP:   0.1110  -------
# -------  Class: chair            AP:   0.1706  -------
# -------  Class: cow              AP:   0.0403  -------
# -------  Class: diningtable      AP:   0.0892  -------
# -------  Class: dog              AP:   0.1338  -------
# -------  Class: horse            AP:   0.0581  -------
# -------  Class: motorbike        AP:   0.0454  -------
# -------  Class: person           AP:   0.4943  -------
# -------  Class: pottedplant      AP:   0.0655  -------
# -------  Class: sheep            AP:   0.0488  -------
# -------  Class: sofa             AP:   0.1230  -------
# -------  Class: train            AP:   0.0855  -------
# -------  Class: tvmonitor        AP:   0.0530  -------
# mAP: 0.1220
# Avg loss: 0.2284033535157933
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.12204935453739285

# %%
plot_losses(train_losses, val_losses, test_frequency, num_epochs)
plot_mAP(train_mAPs, val_mAPs, test_frequency, num_epochs)

# %%
mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)
print("Test mAP: ", mAP_test)
# Out:
# -------  Class: aeroplane        AP:   0.2159  -------
# -------  Class: bicycle          AP:   0.0579  -------
# -------  Class: bird             AP:   0.1165  -------
# -------  Class: boat             AP:   0.1498  -------
# -------  Class: bottle           AP:   0.0603  -------
# -------  Class: bus              AP:   0.0443  -------
# -------  Class: car              AP:   0.1835  -------
# -------  Class: cat              AP:   0.1108  -------
# -------  Class: chair            AP:   0.1550  -------
# -------  Class: cow              AP:   0.0487  -------
# -------  Class: diningtable      AP:   0.0699  -------
# -------  Class: dog              AP:   0.1405  -------
# -------  Class: horse            AP:   0.0560  -------
# -------  Class: motorbike        AP:   0.0414  -------
# -------  Class: person           AP:   0.4982  -------
# -------  Class: pottedplant      AP:   0.0559  -------
# -------  Class: sheep            AP:   0.0647  -------
# -------  Class: sofa             AP:   0.1222  -------
# -------  Class: train            AP:   0.0979  -------
# -------  Class: tvmonitor        AP:   0.0547  -------
# mAP: 0.1172
# Avg loss: 0.22504121139645578
# Test mAP:  0.11720632182568355

# %% [markdown]
# You should notice somewhat poor performance. You could try running AlexNet with an Adam optimizer instead with learning rate 1e-4 to see if that makes a difference. This experiment is not required for the writeup, but it may show you the importance of a good learning rate and optimizer.

# %% [markdown]
# ## Pretrained AlexNet

# %% [markdown]
# Here we look at the impact of pretrained features. This model's weights were trained on ImageNet, which is a much larger dataset. How do pretrained features perform on VOC? Why do you think there is such a large difference in performance?
#
# > Indented block
#
# 1.   List item
# 2.   List item

# %%
num_epochs = 12
test_frequency = 4

# Load Pretrained AlexNet
classifier = torchvision.models.alexnet(pretrained=True)
classifier.classifier._modules['6'] = nn.Linear(4096, 21)
classifier = classifier.to(device)
optimizer = torch.optim.SGD(classifier.parameters(), lr=0.012, momentum=0.95)
# Out:
# Downloading: "https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth" to /root/.cache/torch/checkpoints/alexnet-owt-4df8aa71.pth
# HBox(children=(FloatProgress(value=0.0, max=244418560.0), HTML(value='')))

# %%
classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.21798069775104523
# -------  Class: aeroplane        AP:   0.7139  -------
# -------  Class: bicycle          AP:   0.5385  -------
# -------  Class: bird             AP:   0.7807  -------
# -------  Class: boat             AP:   0.5922  -------
# -------  Class: bottle           AP:   0.2679  -------
# -------  Class: bus              AP:   0.4511  -------
# -------  Class: car              AP:   0.7453  -------
# -------  Class: cat              AP:   0.7182  -------
# -------  Class: chair            AP:   0.5727  -------
# -------  Class: cow              AP:   0.2649  -------
# -------  Class: diningtable      AP:   0.4860  -------
# -------  Class: dog              AP:   0.5822  -------
# -------  Class: horse            AP:   0.6189  -------
# -------  Class: motorbike        AP:   0.6383  -------
# -------  Class: person           AP:   0.8893  -------
# -------  Class: pottedplant      AP:   0.3269  -------
# -------  Class: sheep            AP:   0.2262  -------
# -------  Class: sofa             AP:   0.4156  -------
# -------  Class: train            AP:   0.6916  -------
# -------  Class: tvmonitor        AP:   0.4592  -------
# mAP: 0.5490
# Avg loss: 0.14682084555719413
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.548980631110127
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.12247464805841446
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.10276809334754944
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.10092666745185852
# -------  Class: aeroplane        AP:   0.8202  -------
# -------  Class: bicycle          AP:   0.7111  -------
# -------  Class: bird             AP:   0.8568  -------
# -------  Class: boat             AP:   0.7400  -------
# -------  Class: bottle           AP:   0.3558  -------
# -------  Class: bus              AP:   0.5959  -------
# -------  Class: car              AP:   0.7973  -------
# -------  Class: cat              AP:   0.7585  -------
# -------  Class: chair            AP:   0.6061  -------
# -------  Class: cow              AP:   0.4112  -------
# -------  Class: diningtable      AP:   0.5745  -------
# -------  Class: dog              AP:   0.7107  -------
# -------  Class: horse            AP:   0.6757  -------
# -------  Class: motorbike        AP:   0.7749  -------
# -------  Class: person           AP:   0.9019  -------
# -------  Class: pottedplant      AP:   0.4770  -------
# -------  Class: sheep            AP:   0.4950  -------
# -------  Class: sofa             AP:   0.5089  -------
# -------  Class: train            AP:   0.8575  -------
# -------  Class: tvmonitor        AP:   0.6217  -------
# mAP: 0.6625
# Avg loss: 0.12248187760512035
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 4 is 0.6625346387701769
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.07800239324569702
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.06310863047838211
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.05196336284279823
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.04334617033600807
# -------  Class: aeroplane        AP:   0.8411  -------
# -------  Class: bicycle          AP:   0.7276  -------
# -------  Class: bird             AP:   0.8660  -------
# -------  Class: boat             AP:   0.7606  -------
# -------  Class: bottle           AP:   0.3942  -------
# -------  Class: bus              AP:   0.6172  -------
# -------  Class: car              AP:   0.8172  -------
# -------  Class: cat              AP:   0.7779  -------
# -------  Class: chair            AP:   0.6157  -------
# -------  Class: cow              AP:   0.5059  -------
# -------  Class: diningtable      AP:   0.6137  -------
# -------  Class: dog              AP:   0.7019  -------
# -------  Class: horse            AP:   0.7412  -------
# -------  Class: motorbike        AP:   0.7997  -------
# -------  Class: person           AP:   0.9087  -------
# -------  Class: pottedplant      AP:   0.4663  -------
# -------  Class: sheep            AP:   0.5896  -------
# -------  Class: sofa             AP:   0.5379  -------
# -------  Class: train            AP:   0.8903  -------
# -------  Class: tvmonitor        AP:   0.6300  -------
# mAP: 0.6901
# Avg loss: 0.13365890757710325
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 8 is 0.6901393442290801
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.03775981068611145
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.030740369111299515
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.022930365055799484
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.019780175760388374
# -------  Class: aeroplane        AP:   0.8600  -------
# -------  Class: bicycle          AP:   0.7320  -------
# -------  Class: bird             AP:   0.8458  -------
# -------  Class: boat             AP:   0.7463  -------
# -------  Class: bottle           AP:   0.3558  -------
# -------  Class: bus              AP:   0.6107  -------
# -------  Class: car              AP:   0.8224  -------
# -------  Class: cat              AP:   0.7760  -------
# -------  Class: chair            AP:   0.6003  -------
# -------  Class: cow              AP:   0.5117  -------
# -------  Class: diningtable      AP:   0.5914  -------
# -------  Class: dog              AP:   0.7115  -------
# -------  Class: horse            AP:   0.7441  -------
# -------  Class: motorbike        AP:   0.8076  -------
# -------  Class: person           AP:   0.9053  -------
# -------  Class: pottedplant      AP:   0.4275  -------
# -------  Class: sheep            AP:   0.5770  -------
# -------  Class: sofa             AP:   0.5263  -------
# -------  Class: train            AP:   0.8813  -------
# -------  Class: tvmonitor        AP:   0.6182  -------
# mAP: 0.6826
# Avg loss: 0.16653146843115488
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 12 is 0.6825593999609214

# %%
plot_losses(train_losses, val_losses, test_frequency, num_epochs)
plot_mAP(train_mAPs, val_mAPs, test_frequency, num_epochs)

# %%
mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)
print("Test mAP: ", mAP_test)
# Out:
# -------  Class: aeroplane        AP:   0.8503  -------
# -------  Class: bicycle          AP:   0.7767  -------
# -------  Class: bird             AP:   0.8218  -------
# -------  Class: boat             AP:   0.8001  -------
# -------  Class: bottle           AP:   0.3324  -------
# -------  Class: bus              AP:   0.6305  -------
# -------  Class: car              AP:   0.8417  -------
# -------  Class: cat              AP:   0.7913  -------
# -------  Class: chair            AP:   0.5908  -------
# -------  Class: cow              AP:   0.4940  -------
# -------  Class: diningtable      AP:   0.6414  -------
# -------  Class: dog              AP:   0.7223  -------
# -------  Class: horse            AP:   0.8339  -------
# -------  Class: motorbike        AP:   0.7588  -------
# -------  Class: person           AP:   0.9189  -------
# -------  Class: pottedplant      AP:   0.4596  -------
# -------  Class: sheep            AP:   0.6616  -------
# -------  Class: sofa             AP:   0.5504  -------
# -------  Class: train            AP:   0.8605  -------
# -------  Class: tvmonitor        AP:   0.6382  -------
# mAP: 0.6988
# Avg loss: 0.16155747763812542
# Test mAP:  0.6987523726557323
